# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data = pd.read_csv('C:/Users/student/Desktop/DS/extra_spotify_2000.csv')

# %%
data
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Danceability  \
# 0         adult standards  2004                     157            53
# 1              album rock  2000                     135            50
# 2     alternative hip hop  2001                     168            66
# 3       alternative metal  2007                     173            43
# 4            classic rock  2002                     106            58
# ...                   ...   ...                     ...           ...
# 1989      adult standards  1958                      94            70
# 1990      adult standards  1958                     175            36
# 1991           blues rock  1959                     168            53
# 1992                bebop  1959                     174            45
# 1993      adult standards  1959                     133            49
#
#      Length (Duration)  Speechiness  Popularity
# 0                  201            3          71
# 1                  207            7          39
# 2                  341           17          69
# 3                  269            4          76
# 4                  256            3          59
# ...                ...          ...         ...
# 1989               128            7          63
# 1990               136            6          69
# 1991               162            7          74
# 1992               324            4          65
# 1993               148            3          56
#
# [1994 rows x 10 columns]

# %%
data.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)  Danceability  \
# count  1994.000000  1994.000000             1994.000000   1994.000000
# mean    997.500000  1992.992979              120.215647     53.238215
# std     575.762538    16.116048               28.028096     15.351507
# min       1.000000  1956.000000               37.000000     10.000000
# 25%     499.250000  1979.000000               99.000000     43.000000
# 50%     997.500000  1993.000000              119.000000     53.000000
# 75%    1495.750000  2007.000000              136.000000     64.000000
# max    1994.000000  2019.000000              206.000000     96.000000
#
#        Speechiness  Popularity
# count  1994.000000  1994.00000
# mean      4.994985    59.52658
# std       4.401566    14.35160
# min       2.000000    11.00000
# 25%       3.000000    49.25000
# 50%       4.000000    62.00000
# 75%       5.000000    71.00000
# max      55.000000   100.00000

# %%
y = data['Popularity'] # dependent variable
x1 = data['Beats Per Minute (BPM)'] # independent variable

# %%
plt.scatter(x1,y) # scatter plot
plt.xlabel('Danceability', fontsize = 20) # x label
plt.ylabel('Beats Per Minute (BPM)', fontsize = 20) # y label
plt.show() # show plot

# %%
x = sm.add_constant(x1) # add constant
results = sm.OLS(y,x).fit() # fit model
results.summary() # show results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Popularity   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.02016
# Date:                Fri, 06 Oct 2023   Prob (F-statistic):              0.887
# Time:                        16:06:42   Log-Likelihood:                -8140.6
# No. Observations:                1994   AIC:                         1.629e+04
# Df Residuals:                    1992   BIC:                         1.630e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     59.7224      1.416     42.172      0.000      56.945      62.500
# Beats Per Minute (BPM)    -0.0016      0.011     -0.142      0.887      -0.024       0.021
# ==============================================================================
# Omnibus:                       85.397   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.724
# Skew:                          -0.533   Prob(JB):                     1.64e-21
# Kurtosis:                       2.882   Cond. No.                         544.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(x1,y) # scatter plot
yhat = -0.0016*x1 + 59.7224
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line') # plot regression line
plt.xlabel('Danceability', fontsize = 20) # x label
plt.ylabel('Beats Per Minute (BPM)', fontsize = 20) # y label
plt.show() # show plot

# %%
y = data['Popularity'] # dependent variable
x1 = data['Speechiness'] # independent variable

# %%
plt.scatter(x1,y) # scatter plot
plt.xlabel('Danceability', fontsize = 20) # x label
plt.ylabel('Speechiness', fontsize = 20) # y label
plt.show() # show plot

# %%
x = sm.add_constant(x1) # add constant
results = sm.OLS(y,x).fit() # fit model
results.summary() # show results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Popularity   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     25.16
# Date:                Fri, 06 Oct 2023   Prob (F-statistic):           5.74e-07
# Time:                        16:25:54   Log-Likelihood:                -8128.1
# No. Observations:                1994   AIC:                         1.626e+04
# Df Residuals:                    1992   BIC:                         1.627e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          57.7076      0.483    119.410      0.000      56.760      58.655
# Speechiness     0.3642      0.073      5.016      0.000       0.222       0.507
# ==============================================================================
# Omnibus:                       87.282   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.069
# Skew:                          -0.540   Prob(JB):                     5.07e-22
# Kurtosis:                       2.878   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(x1,y) # scatter plot
yhat = 0.3642*x1 + 57.7076
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line') # plot regression line
plt.xlabel('Danceability', fontsize = 20) # x label
plt.ylabel('Speechiness', fontsize = 20) # y label
plt.show() # show plot
